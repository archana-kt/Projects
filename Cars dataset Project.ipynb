# %% [markdown]
# # Python Data Analysis Project

# %% [markdown]
# ## Cars dataset

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/archanaqueen/Desktop/i18n/Python Projects/cars.csv")

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
# Explore the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
data.shape
# Out:
# (8128, 13)

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
data.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
data.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 8123  False  False          False      False  False        False
# 8124  False  False          False      False  False        False
# 8125  False  False          False      False  False        False
# 8126  False  False          False      False  False        False
# 8127  False  False          False      False  False        False
#
#       transmission  owner  mileage  engine  max_power  torque  seats
# 0            False  False    False   False      False   False  False
# ...

# %%
data.isnull().sum() # it shows individual columns
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
# To fill the null values, we need to take mean of that column

# %%
data["seats"] = pd.to_numeric(data["seats"], errors='coerce')

# %%
data["seats"].fillna(data["seats"].mean(), inplace = True)

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage   engine   max_power  \
# 0  Individual       Manual   First Owner      NaN  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner      NaN  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner      NaN  1497 CC      78 bhp
# 3  Individual       Manual   First Owner      NaN  1396 CC      90 bhp
# 4  Individual       Manual   First Owner      NaN  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data.isnull().sum()
# Out:
# name                0
# year                0
# selling_price       0
# km_driven           0
# fuel                0
# seller_type         0
# transmission        0
# owner               0
# mileage          8128
# engine            221
# max_power         215
# torque            222
# seats               0
# dtype: int64

# %%
# See now there is no null values

# %% [markdown]
# ## Queries

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage   engine   max_power  \
# 0  Individual       Manual   First Owner      NaN  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner      NaN  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner      NaN  1497 CC      78 bhp
# 3  Individual       Manual   First Owner      NaN  1396 CC      90 bhp
# 4  Individual       Manual   First Owner      NaN  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# # 1) What are the different types of transmission in the dataset. What is the occurence of each transmission in the data?

# %%
data["transmission"]
# Out:
# 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual
#          ...
# 8123    Manual
# 8124    Manual
# 8125    Manual
# 8126    Manual
# 8127    Manual
# Name: transmission, Length: 8128, dtype: object

# %%
data["transmission"].value_counts()
# Out:
# Manual       7078
# Automatic    1050
# Name: transmission, dtype: int64

# %% [markdown]
# # Filtering

# %% [markdown]
# # 2) Show all the records where the owner is First owner or Second owner

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage   engine   max_power  \
# 0  Individual       Manual   First Owner      NaN  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner      NaN  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner      NaN  1497 CC      78 bhp
# 3  Individual       Manual   First Owner      NaN  1396 CC      90 bhp
# 4  Individual       Manual   First Owner      NaN  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
data['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
data.nunique()
# Out:
# name             2058
# year               29
# selling_price     677
# km_driven         921
# fuel                4
# seller_type         3
# transmission        2
# owner               5
# mileage             0
# engine            121
# max_power         322
# torque            441
# seats              10
# dtype: int64

# %%
data["owner"] == "First Owner"
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 8123     True
# 8124    False
# 8125     True
# 8126     True
# 8127     True
# Name: owner, Length: 8128, dtype: bool

# %%
data[data["owner"] == "First Owner"]
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 3         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 5     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# 6      Maruti Wagon R LXI DUO BSIII  2007          96000     175000     LPG
# ...                             ...   ...            ...        ...     ...
# 8120        Hyundai Santro Xing GLS  2008         120000     191000  Petrol
# 8123              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8125         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
# 8127                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.groupby("owner").get_group("First Owner")
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 3         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 5     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# 6      Maruti Wagon R LXI DUO BSIII  2007          96000     175000     LPG
# ...                             ...   ...            ...        ...     ...
# 8120        Hyundai Santro Xing GLS  2008         120000     191000  Petrol
# 8123              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8125         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
# 8127                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data["owner"] == "Second Owner"
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 8123    False
# 8124    False
# 8125    False
# 8126    False
# 8127    False
# Name: owner, Length: 8128, dtype: bool

# %%
data[data["owner"] == "Second Owner"]
# Out:
#                                    name  year  selling_price  km_driven  \
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 10      Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                        Maruti Zen LX  2005          92000     100000
# 12               Maruti Swift Dzire VDi  2009         280000     140000
# ...                                 ...   ...            ...        ...
# 8104          Honda City 2017-2020 VTEC  2006         160000      70000
# 8105                 Honda City 1.3 EXI  2004         135000     120000
# 8106               Hyundai Verna 1.6 SX  2012         450000     128000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
#
#         fuel seller_type transmission         owner  mileage   engine  \
# ...

# %%
data.groupby("owner").get_group("Second Owner")
# Out:
#                                    name  year  selling_price  km_driven  \
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 10      Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                        Maruti Zen LX  2005          92000     100000
# 12               Maruti Swift Dzire VDi  2009         280000     140000
# ...                                 ...   ...            ...        ...
# 8104          Honda City 2017-2020 VTEC  2006         160000      70000
# 8105                 Honda City 1.3 EXI  2004         135000     120000
# 8106               Hyundai Verna 1.6 SX  2012         450000     128000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
#
#         fuel seller_type transmission         owner  mileage   engine  \
# ...

# %%
data[data["owner"].isin(["First Owner","Second Owner"])]
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 3         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 5     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# ...                             ...   ...            ...        ...     ...
# 8122     Hyundai i20 Magna 1.4 CRDi  2014         475000      80000  Diesel
# 8123              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8125         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
# 8127                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data["owner"].value_counts()
# Out:
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
5289 + 2105
# Out:
# 7394

# %% [markdown]
# # Removing unwanted records

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage   engine   max_power  \
# 0  Individual       Manual   First Owner      NaN  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner      NaN  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner      NaN  1497 CC      78 bhp
# 3  Individual       Manual   First Owner      NaN  1396 CC      90 bhp
# 4  Individual       Manual   First Owner      NaN  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# # 3) Remove all the records where selling_price above 2 lakhs

# %%
data["selling_price"] > 200000
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 8123     True
# 8124    False
# 8125     True
# 8126     True
# 8127     True
# Name: selling_price, Length: 8128, dtype: bool

# %%
data[data["selling_price"] > 200000]
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 3         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 5     Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
# 8                  Toyota Etios VXD  2011         350000      90000  Diesel
# ...                             ...   ...            ...        ...     ...
# 8122     Hyundai i20 Magna 1.4 CRDi  2014         475000      80000  Diesel
# 8123              Hyundai i20 Magna  2013         320000     110000  Petrol
# 8125         Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126                Tata Indigo CR4  2013         290000      25000  Diesel
# 8127                Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
data.shape
# Out:
# (8128, 13)

# %% [raw]
# # To remove those records, we can use ~

# %%
data[~(data["selling_price"] > 200000)]
# Out:
#                                       name  year  selling_price  km_driven  \
# 2                 Honda City 2017-2020 EXi  2006         158000     140000
# 4                   Maruti Swift VXI BSIII  2007         130000     120000
# 6             Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                       Maruti 800 DX BSII  2001          45000       5000
# 9     Ford Figo Diesel Celebration Edition  2013         200000     169000
# ...                                    ...   ...            ...        ...
# 8105                    Honda City 1.3 EXI  2004         135000     120000
# 8114                       Maruti Alto LXi  2011         200000      73000
# 8115                         Maruti 800 AC  1997          40000     120000
# 8120               Hyundai Santro Xing GLS  2008         120000     191000
# 8124                 Hyundai Verna CRDi SX  2007         135000     119000
#
# ...

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
8128 - 6738
# Out:
# 1390

# %% [markdown]
# # Applying function on a column

# %% [markdown]
# # 4) Increase all the values of "engine" column by 5

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage   engine   max_power  \
# 0  Individual       Manual   First Owner      NaN  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner      NaN  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner      NaN  1497 CC      78 bhp
# 3  Individual       Manual   First Owner      NaN  1396 CC      90 bhp
# 4  Individual       Manual   First Owner      NaN  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data['km_driven']
# Out:
# 0       145500
# 1       120000
# 2       140000
# 3       127000
# 4       120000
#          ...
# 8123    110000
# 8124    119000
# 8125    120000
# 8126     25000
# 8127     25000
# Name: km_driven, Length: 8128, dtype: int64

# %%
type(data['km_driven'])
# Out:
# pandas.core.series.Series

# %%
data['km_driven'].apply(lambda x:x + 3) # apply can applicable to both series and dataframe
# Out:
# 0       145503
# 1       120003
# 2       140003
# 3       127003
# 4       120003
#          ...
# 8123    110003
# 8124    119003
# 8125    120003
# 8126     25003
# 8127     25003
# Name: km_driven, Length: 8128, dtype: int64

# %%
data['km_driven'] = data['km_driven'].apply(lambda x:x + 3)

# %%
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145503  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120003  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140003  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127003  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120003  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110003  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119003  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120003  Diesel
# 8126               Tata Indigo CR4  2013         290000      25003  Diesel
# 8127               Tata Indigo CR4  2013         290000      25003  Diesel
#
# ...
