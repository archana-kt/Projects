# %% [markdown]
# # Python Data Analysis Project

# %% [markdown]
# ## The Weather Dataset

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("/Users/archanaqueen/Desktop/i18n/Python Projects/weather.csv")

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
# To explore the data

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.shape # gives total number of rows and columns
# Out:
# (366, 22)

# %%
data.index # range of the dataframe
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
data.columns # to know the column names
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data.dtypes # It shows datatype of each column
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
data['MinTemp'].unique() # shows all unique values in each column
# Out:
# array([ 8. , 14. , 13.7, 13.3,  7.6,  6.2,  6.1,  8.3,  8.8,  8.4,  9.1,
#         8.5, 10.1, 12.1, 12.4, 13.8, 11.7, 15.6, 15.3, 16.4, 12.8, 12. ,
#        15.4, 12.9, 15.1, 13.6, 11.6, 16.6, 14.5, 16.3, 17.2, 16.5, 15. ,
#        14.9, 11.8,  9.6,  8.9, 15.5, 10.8,  7.5, 12.6, 14.8, 19.9,  9.2,
#        11.3,  9.8, 14.3, 14.4, 15.9, 16.7, 17.5, 14.7, 20.9, 17. , 16. ,
#        17.9, 15.2, 10. ,  9.9, 10.3, 12.7, 13.2, 18. , 17.6, 17.1, 18.2,
#        16.8, 10.4,  8.6, 11.2, 11.4, 11.5, 13. ,  7.7,  4.4,  7.4,  9.5,
#        12.5, 13.9, 12.3, 13.1,  7.1,  4.2,  3.5,  5.3,  7. ,  0.4,  3.2,
#         5.9,  8.1,  6.9,  5.6,  7.2,  5.4,  6.3,  7.9,  2.4,  2.5,  5. ,
#         3.8,  4.3, -2.1, -1.8,  2.1,  0.5, -0.9, -0.2,  0.1,  1.5,  9.4,
#         1.3,  2.2, -0.4,  4.5, -2.7,  0.3,  1.2, -0.3,  4.7,  4.9,  1.4,
#        -0.1,  0.6,  4.6, 10.6,  7.8, 10.2,  7.3,  8.7,  1. ,  6.4,  4. ,
#         0.9,  0.8, -1.5,  6.6, -1.6, -3.1, -0.6,  3. ,  2.9, -1.3,  1.8,
# ...

# %%
len(data['MinTemp'].unique())
# Out:
# 180

# %%
# nunique shows total no.of values in each column.It can be applied both in single column or whole dataframe

# %%
data.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
data['WindGustDir'].nunique()
# Out:
# 16

# %%
data['MinTemp'].nunique()
# Out:
# 180

# %%
# count shows total number of non-null values in each column or entire dataframe

# %%
data.count()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
data['RainToday'].count()
# Out:
# 366

# %%
# value_counts shows all their unique values with their count. It can be applied on a single column only.

# %%
data['RainToday'].value_counts()
# Out:
# No     300
# Yes     66
# Name: RainToday, dtype: int64

# %%
data.info() # basic info of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %% [markdown]
# ## Queries and Answers

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # 1) Find all the unique "WindGustSpeed" values in the data

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.nunique() # it shows for all. here windgustspeed has 35 values unique
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
data["WindGustSpeed"].nunique()
# Out:
# 35

# %%
# Answer

# %%
data["WindGustSpeed"].unique()
# Out:
# array([30., 39., 85., 54., 50., 44., 43., 41., 48., 31., 46., 52., 33.,
#        59., 26., 28., 35., 22., 76., 65., 57., 69., 61., 24., 83., 63.,
#        17., 20., nan, 15., 13., 70., 78., 67., 98., 80.])

# %%
# including nan means it shows 36

# %% [markdown]
# # 2) Find the number of times when there is a rain tomorrow is 'Yes'?

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# value_counts

# %%
data["RainTomorrow"]
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 361     No
# 362     No
# 363     No
# 364     No
# 365     No
# Name: RainTomorrow, Length: 366, dtype: object

# %%
data["RainTomorrow"].value_counts()
# Out:
# No     300
# Yes     66
# Name: RainTomorrow, dtype: int64

# %%
# Filtering

# %%
data["RainTomorrow"] == "Yes"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: RainTomorrow, Length: 366, dtype: bool

# %%
data[data["RainTomorrow"] == "Yes"]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 326      3.2     21.9       0.0          6.8       5.2          NW
# 337     16.8     28.9       0.0         10.0      10.8         NNW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 340     11.2     18.0       0.0          4.8       8.4           W
# 347      6.7     26.1       0.0          6.2       7.5         SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
# groupby

# %%
data.groupby("RainTomorrow").get_group("Yes")
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 326      3.2     21.9       0.0          6.8       5.2          NW
# 337     16.8     28.9       0.0         10.0      10.8         NNW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 340     11.2     18.0       0.0          4.8       8.4           W
# 347      6.7     26.1       0.0          6.2       7.5         SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # 3) Find the number of times when the "cloud9am at 7"

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# value_counts

# %%
data["Cloud9am"]
# Out:
# 0      7
# 1      5
# 2      8
# 3      2
# 4      7
#       ..
# 361    1
# 362    0
# 363    3
# 364    6
# 365    1
# Name: Cloud9am, Length: 366, dtype: int64

# %%
data["Cloud9am"].value_counts()
# Out:
# 1    116
# 7     86
# 8     40
# 0     33
# 6     25
# 5     23
# 2     17
# 3     17
# 4      9
# Name: Cloud9am, dtype: int64

# %%
# Filtering

# %%
data["Cloud9am"] == 7
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: Cloud9am, Length: 366, dtype: bool

# %%
data[data["Cloud9am"] == 7]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 8        8.8     19.5       0.0          4.0       4.1           S
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 321      0.7     14.1       0.0          5.6       9.0         ENE
# 327      7.8     16.2      17.4          6.4       7.9          NW
# 348     11.9     21.1      13.2          6.6       NaN          NW
# 349      9.2     19.6       0.6          3.4      10.4         ENE
# 355      9.0     20.6       0.0          9.0       6.2         ENE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
# groupby

# %%
data.groupby("Cloud9am").get_group(7)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 8        8.8     19.5       0.0          4.0       4.1           S
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 321      0.7     14.1       0.0          5.6       9.0         ENE
# 327      7.8     16.2      17.4          6.4       7.9          NW
# 348     11.9     21.1      13.2          6.6       NaN          NW
# 349      9.2     19.6       0.6          3.4      10.4         ENE
# 355      9.0     20.6       0.0          9.0       6.2         ENE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # 4) Find out all the Null values in the data

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.isnull()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      False    False     False        False     False        False
# 1      False    False     False        False     False        False
# 2      False    False     False        False     False        False
# 3      False    False     False        False     False        False
# 4      False    False     False        False     False        False
# ..       ...      ...       ...          ...       ...          ...
# 361    False    False     False        False     False        False
# 362    False    False     False        False     False        False
# 363    False    False     False        False     False        False
# 364    False    False     False        False     False        False
# 365    False    False     False        False     False        False
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
# To avoid this as in bollean form. We use sum()

# %%
data.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
data.notnull().sum() # it shows not null values
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
# 5) Rename the column name "RainToday" of the dataframe to "WeatherConditionToday"

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.rename(columns = {"RainToday" : "WeatherConditionToday"})
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.rename(columns = {"RainToday" : "WeatherConditionToday"}, inplace=True)

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0       1019.7       1015.0         7         7     14.4     23.6
# ...

# %% [markdown]
# # 6) What is the mean of the "Evaporation"?

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0       1019.7       1015.0         7         7     14.4     23.6
# ...

# %%
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
data["Evaporation"].mean()
# Out:
# 4.521857923497269

# %%
# Manual calculation

# %%
sum = data["Evaporation"].sum()

# %%
sum
# Out:
# 1655.0

# %%
length = len(data["Evaporation"])

# %%
length
# Out:
# 366

# %%
mean = sum / length

# %%
mean
# Out:
# 4.521857923497268

# %% [markdown]
# # 7) What is the Standard Deviation of "Pressure9am" in this data?

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0       1019.7       1015.0         7         7     14.4     23.6
# ...

# %%
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
data["Pressure9am"]
# Out:
# 0      1019.7
# 1      1012.4
# 2      1009.5
# 3      1005.5
# 4      1018.3
#         ...
# 361    1016.1
# 362    1020.0
# 363    1024.0
# 364    1021.0
# 365    1009.6
# Name: Pressure9am, Length: 366, dtype: float64

# %%
data["Pressure9am"].std()
# Out:
# 6.686211582894859

# %%
# Manual calculation

# %% [raw]
# std = sqrt((x - x^)^2 / n)

# %%
x = data["Pressure9am"]

# %%
x
# Out:
# 0      1019.7
# 1      1012.4
# 2      1009.5
# 3      1005.5
# 4      1018.3
#         ...
# 361    1016.1
# 362    1020.0
# 363    1024.0
# 364    1021.0
# 365    1009.6
# Name: Pressure9am, Length: 366, dtype: float64

# %%
x_bar = data["Pressure9am"].mean()

# %%
x_bar
# Out:
# 1019.7090163934431

# %%
sum = data["Pressure9am"].sum()

# %%
sum
# Out:
# 373213.50000000006

# %%
length = len(data["Pressure9am"])

# %%
length
# Out:
# 366

# %%
mean = sum / length

# %%
mean
# Out:
# 1019.7090163934428

# %%
data["Pressure9am"].var()
# Out:
# 44.70542533123737

# %%
np.sqrt(data["Pressure9am"].var())
# Out:
# 6.686211582894859

# %%
data["Pressure9am"].std()
# Out:
# 6.686211582894859

# %% [markdown]
# # 8) What is the standard deviation of "Sunshine"?

# %%
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
data["Sunshine"].std()
# Out:
# 3.4815171624059222

# %% [markdown]
# # 9) Find all the instances when WindGustDir is "NW"?

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0       1019.7       1015.0         7         7     14.4     23.6
# ...

# %%
data["WindGustDir"]
# Out:
# 0       NW
# 1      ENE
# 2       NW
# 3       NW
# 4      SSE
#       ...
# 361    NNW
# 362      N
# 363    ESE
# 364     NW
# 365     NW
# Name: WindGustDir, Length: 366, dtype: object

# %%
# value_counts

# %%
data["WindGustDir"].value_counts()
# Out:
# NW     73
# NNW    44
# E      37
# WNW    35
# ENE    30
# ESE    23
# S      22
# N      21
# W      20
# NE     16
# SSE    12
# SE     12
# NNE     8
# SSW     5
# SW      3
# WSW     2
# Name: WindGustDir, dtype: int64

# %%
# Filtering

# %%
data["WindGustDir"] == "NW"
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364     True
# 365     True
# Name: WindGustDir, Length: 366, dtype: bool

# %%
data[data["WindGustDir"] == "NW"]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 13      12.1     30.9       0.0          6.2      12.4          NW
# 14      10.1     31.2       0.0          8.8      13.1          NW
# ..       ...      ...       ...          ...       ...         ...
# 352      6.7     24.7       0.0          5.4       8.6          NW
# 353      8.3     28.5       0.0          5.8       9.8          NW
# 354     11.3     27.4       0.2          7.6      12.1          NW
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # 10) Find all the instances when "WindSpeed9am is above 7.0" and "Temp9am is 14"?

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0       1019.7       1015.0         7         7     14.4     23.6
# ...

# %%
data["WindSpeed9am"]
# Out:
# 0       6.0
# 1       4.0
# 2       6.0
# 3      30.0
# 4      20.0
#        ...
# 361     7.0
# 362     2.0
# 363    11.0
# 364     6.0
# 365    31.0
# Name: WindSpeed9am, Length: 366, dtype: float64

# %%
data["WindSpeed9am"] > 7.0
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 361    False
# 362    False
# 363     True
# 364    False
# 365     True
# Name: WindSpeed9am, Length: 366, dtype: bool

# %%
data[data["WindSpeed9am"] > 7.0]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# ..       ...      ...       ...          ...       ...         ...
# 355      9.0     20.6       0.0          9.0       6.2         ENE
# 356      3.4     15.0       0.8          4.8      11.7           S
# 357      3.2     18.0       0.0          7.4      12.2         SSE
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3             54.0        WNW          W          30.0  ...           56
# ...

# %%
data["Temp9am"] == 14
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: Temp9am, Length: 366, dtype: bool

# %%
data[data["Temp9am"] == 14]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 22      12.8     18.5      25.8          2.8       0.6         ESE
# 101      9.1     23.1       0.0          5.8       9.6         ENE
# 128      9.5     27.4       3.0          4.8      11.5         NNW
# 142     11.6     19.6       0.0          2.8       1.6           E
# 161      7.2     22.9       0.0          2.2       9.5           E
# 169      7.9     19.7       0.0          3.2       8.3         ESE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 22            28.0          S         SE          13.0  ...           79
# 101           41.0        SSE          W          17.0  ...           37
# 128           24.0        SSE        NNW           6.0  ...           39
# 142           33.0         SE        ESE           6.0  ...           64
# 161           26.0        NNW          N           4.0  ...           28
# ...

# %%
data[(data["WindSpeed9am"] > 7.0) & (data["Temp9am"] == 14)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 22      12.8     18.5      25.8          2.8       0.6         ESE
# 101      9.1     23.1       0.0          5.8       9.6         ENE
# 169      7.9     19.7       0.0          3.2       8.3         ESE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 22            28.0          S         SE          13.0  ...           79
# 101           41.0        SSE          W          17.0  ...           37
# 169           48.0        SSE        ENE          17.0  ...           43
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 22          1024       1014.9         8         8     14.0     16.8
# 101         1024       1011.4         1         7     14.0     21.4
# 169         1024       1024.1         3         6     14.0     19.1
#
#      WeatherConditionToday  RISK_MM RainTomorrow
# 22                     Yes      0.4           No
# ...

# %% [markdown]
# # 11) What is the mean value of each column against each "RainTomorrow"?

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1024       1015.0         7         7     14.4     23.6
# ...

# %%
data.groupby("RainTomorrow").mean()
# Out:
#                 MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# RainTomorrow
# No             6.607333  20.396000  1.164000     4.408667  8.540604
# Yes           10.257576  21.251515  2.630303     5.036364  5.015385
#
#               WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# RainTomorrow
# No                38.308725      9.319728     17.810000    70.896667
# Yes               46.757576     11.153846     18.787879    77.212121
#
#               Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# RainTomorrow
# No              41.623333       1024.0  1017.932333  3.496667  3.540000
# Yes             57.681818       1024.0  1011.710606  5.681818  6.227273
#
#                 Temp9am    Temp3pm   RISK_MM
# RainTomorrow
# No            11.878000  19.196333  0.056667
# Yes           14.542424  19.387879  7.663636

# %% [markdown]
# # 12) What is the minimum and maximum value of each column against "RainTomorrow"?

# %%
data.groupby("RainTomorrow").min()
# Out:
# /var/folders/5f/zvvxs6012zn4htwxbbkh2mvh0000gn/T/ipykernel_3299/2902472375.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   data.groupby("RainTomorrow").min()
#               MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# RainTomorrow
# No               -5.3      7.6       0.0          0.2       0.0
# Yes              -2.3      8.7       0.0          0.6       0.0
#
#               WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# RainTomorrow
# No                     13.0           0.0             2           36
# Yes                    17.0           0.0             0           44
#
#               Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# RainTomorrow
# No                     13         1024        997.5         0         0
# ...

# %%
data.groupby("RainTomorrow").max()
# Out:
# /var/folders/5f/zvvxs6012zn4htwxbbkh2mvh0000gn/T/ipykernel_3299/2813169628.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data.groupby("RainTomorrow").max()
#               MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# RainTomorrow
# No               17.9     35.8      25.8         12.6      13.6
# Yes              20.9     35.7      39.8         13.8      12.1
#
#               WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# RainTomorrow
# No                     78.0          35.0            50           99
# Yes                    98.0          41.0            52           99
#
#               Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# RainTomorrow
# No                     86         1024       1033.2         8         8
# ...

# %% [markdown]
# # 13) Show all the records where "RainTomorrow" is "Yes"

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1024       1015.0         7         7     14.4     23.6
# ...

# %%
data["RainTomorrow"] == "Yes"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: RainTomorrow, Length: 366, dtype: bool

# %%
data[data["RainTomorrow"] == "Yes"]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 326      3.2     21.9       0.0          6.8       5.2          NW
# 337     16.8     28.9       0.0         10.0      10.8         NNW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 340     11.2     18.0       0.0          4.8       8.4           W
# 347      6.7     26.1       0.0          6.2       7.5         SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.groupby("RainTomorrow").get_group("Yes")
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 326      3.2     21.9       0.0          6.8       5.2          NW
# 337     16.8     28.9       0.0         10.0      10.8         NNW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 340     11.2     18.0       0.0          4.8       8.4           W
# 347      6.7     26.1       0.0          6.2       7.5         SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # 14) Find all the instances when "RainTomorrow is Yes" or "Rainfall is above 35"

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1024       1015.0         7         7     14.4     23.6
# ...

# %%
data["RainTomorrow"] == "Yes"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: RainTomorrow, Length: 366, dtype: bool

# %%
data[data["RainTomorrow"] == "Yes"]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 326      3.2     21.9       0.0          6.8       5.2          NW
# 337     16.8     28.9       0.0         10.0      10.8         NNW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 340     11.2     18.0       0.0          4.8       8.4           W
# 347      6.7     26.1       0.0          6.2       7.5         SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data["Rainfall"] > 35
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: Rainfall, Length: 366, dtype: bool

# %%
data[data["Rainfall"] > 35]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3     13.3     15.5      39.8          7.2       9.1          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3           54.0        WNW          W          30.0  ...           56
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 3         1024       1007.0         2         7     13.5     14.1
#
#    WeatherConditionToday  RISK_MM RainTomorrow
# 3                    Yes      2.8          Yes
#
# [1 rows x 22 columns]

# %%
data[(data["RainTomorrow"] == "Yes") | (data["Rainfall"] > 35)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 326      3.2     21.9       0.0          6.8       5.2          NW
# 337     16.8     28.9       0.0         10.0      10.8         NNW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 340     11.2     18.0       0.0          4.8       8.4           W
# 347      6.7     26.1       0.0          6.2       7.5         SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # 15) 14) Find all the instances when "RainTomorrow is No" or "Rainfall is below 35

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1024       1015.0         7         7     14.4     23.6
# ...

# %%
data[(data["RainTomorrow"] == "No") | (data["Rainfall"] < 35)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...
