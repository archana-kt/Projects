# %% [markdown]
# # Python Project

# %% [markdown]
# # Covid-19 dataset

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/archanaqueen/Desktop/i18n/Python Projects/Covid-19 dataset/covid/data/reference.csv")

# %%
data
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 0            4   AF  AFG    4.0      NaN         NaN            NaN
# 1            8   AL  ALB    8.0      NaN         NaN            NaN
# 2           10   AQ  ATA   10.0      NaN         NaN            NaN
# 3           12   DZ  DZA   12.0      NaN         NaN            NaN
# 4           20   AD  AND   20.0      NaN         NaN            NaN
# ...        ...  ...  ...    ...      ...         ...            ...
# 4311  84056037   US  USA  840.0  56037.0  Sweetwater        Wyoming
# 4312  84056039   US  USA  840.0  56039.0       Teton        Wyoming
# 4313  84056041   US  USA  840.0  56041.0       Uinta        Wyoming
# 4314  84056043   US  USA  840.0  56043.0    Washakie        Wyoming
# 4315  84056045   US  USA  840.0  56045.0      Weston        Wyoming
#
#      Country_Region        Lat       Long_             Combined_Key  \
# 0       Afghanistan  33.939110   67.709953              Afghanistan
# ...

# %% [markdown]
# # Finding missing values

# %%
data.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   10   AQ  ATA   10.0   NaN    NaN            NaN     Antarctica -71.94990
# 3   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 4   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2  23.347000   Antarctica         NaN
# 3   1.659600      Algeria  43851043.0
# 4   1.521800      Andorra     77265.0

# %%
data.isnull().sum()
# Out:
# UID                 0
# iso2                5
# iso3                4
# code3               4
# FIPS              932
# Admin2            973
# Province_State    199
# Country_Region      0
# Lat               148
# Long_             148
# Combined_Key        0
# Population        151
# dtype: int64

# %%
data.count()
# Out:
# UID               4316
# iso2              4311
# iso3              4312
# code3             4312
# FIPS              3384
# Admin2            3343
# Province_State    4117
# Country_Region    4316
# Lat               4168
# Long_             4168
# Combined_Key      4316
# Population        4165
# dtype: int64

# %%
# To view the missing values, we can plot using seaborn and matplot

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
# See that white is the vaccum or null values

# %% [markdown]
# # 1) Show the number of Confirmed, Deaths and Recovered cases in each Region

# %%
data2 = pd.read_csv("/Users/archanaqueen/Desktop/i18n/Python Projects/Covid-19 dataset/country_wise_latest.csv")

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
data2.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
data2.shape
# Out:
# (187, 15)

# %%
# Finding missing values

# %%
data2.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
# No missing values

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2[["Confirmed","Deaths","Recovered","WHO Region"]]
# Out:
#      Confirmed  Deaths  Recovered             WHO Region
# 0        36263    1269      25198  Eastern Mediterranean
# 1         4880     144       2745                 Europe
# 2        27973    1163      18837                 Africa
# 3          907      52        803                 Europe
# 4          950      41        242                 Africa
# ..         ...     ...        ...                    ...
# 182      10621      78       3752  Eastern Mediterranean
# 183         10       1          8                 Africa
# 184       1691     483        833  Eastern Mediterranean
# 185       4552     140       2815                 Africa
# 186       2704      36        542                 Africa
#
# [187 rows x 4 columns]

# %%
data2.groupby("WHO Region").sum().head(50)
# Out:
#                        Confirmed  Deaths  Recovered   Active  New cases  \
# WHO Region
# Africa                    723207   12223     440645   270339      12176
# Americas                 8839286  342732    4468616  4027938     129531
# Eastern Mediterranean    1490744   38339    1201400   251005      12410
# Europe                   3299523  211144    1993723  1094656      22294
# South-East Asia          1835297   41349    1156933   637015      48993
# Western Pacific           292428    8249     206770    77409       3289
#
#                        New deaths  New recovered  Deaths / 100 Cases  \
# WHO Region
# Africa                        353          14563              110.71
# Americas                     3555          94776              106.84
# Eastern Mediterranean         445          14843               78.39
# Europe                        304          11732              235.11
# South-East Asia               734          37582               12.96
# ...

# %%
data2.groupby("WHO Region")["Confirmed"].sum()
# Out:
# WHO Region
# Africa                    723207
# Americas                 8839286
# Eastern Mediterranean    1490744
# Europe                   3299523
# South-East Asia          1835297
# Western Pacific           292428
# Name: Confirmed, dtype: int64

# %%
# To show it clearly

# %%
data2.groupby("WHO Region")["Confirmed"].sum().sort_values(ascending = False).head(10)
# Out:
# WHO Region
# Americas                 8839286
# Europe                   3299523
# South-East Asia          1835297
# Eastern Mediterranean    1490744
# Africa                    723207
# Western Pacific           292428
# Name: Confirmed, dtype: int64

# %%
# It shows in descending order

# %%
data2.groupby("WHO Region")[["Confirmed","Deaths"]].sum()
# Out:
#                        Confirmed  Deaths
# WHO Region
# Africa                    723207   12223
# Americas                 8839286  342732
# Eastern Mediterranean    1490744   38339
# Europe                   3299523  211144
# South-East Asia          1835297   41349
# Western Pacific           292428    8249

# %%
data2.groupby("WHO Region")[["Confirmed","Deaths","Recovered"]].sum()
# Out:
#                        Confirmed  Deaths  Recovered
# WHO Region
# Africa                    723207   12223     440645
# Americas                 8839286  342732    4468616
# Eastern Mediterranean    1490744   38339    1201400
# Europe                   3299523  211144    1993723
# South-East Asia          1835297   41349    1156933
# Western Pacific           292428    8249     206770

# %% [markdown]
# # 2) Remove all the records where Confirmed Cases is less than 100000

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2["Confirmed"]
# Out:
# 0      36263
# 1       4880
# 2      27973
# 3        907
# 4        950
#        ...
# 182    10621
# 183       10
# 184     1691
# 185     4552
# 186     2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
data2["Confirmed"] < 100000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 182    True
# 183    True
# 184    True
# 185    True
# 186    True
# Name: Confirmed, Length: 187, dtype: bool

# %%
data2[data2["Confirmed"] < 100000]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data2[~(data2["Confirmed"] < 100000)]
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 6         Argentina     167416    3059      72575    91782       4890
# 13       Bangladesh     226225    2965     125683    97577       2772
# 23           Brazil    2442375   87618    1846641   508116      23284
# 32           Canada     116458    8944          0   107514        682
# 35            Chile     347923    9187     319954    18782       2133
# 37         Colombia     257101    8777     131161   117163      16306
# 61           France     220352   30212      81212   108928       2551
# 65          Germany     207112    9125     190314     7673        445
# 79            India    1480073   33408     951166   495499      44457
# 80        Indonesia     100303    4838      58173    37292       1525
# 81             Iran     293606   15912     255144    22550       2434
# 82             Iraq     112585    4458      77144    30983       2553
# ...

# %%
data2
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
# To remove permanently, we need to assign this statement to data2

# %%
data2 = data2[~(data2["Confirmed"] < 100000)]

# %%
data2
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 6         Argentina     167416    3059      72575    91782       4890
# 13       Bangladesh     226225    2965     125683    97577       2772
# 23           Brazil    2442375   87618    1846641   508116      23284
# 32           Canada     116458    8944          0   107514        682
# 35            Chile     347923    9187     319954    18782       2133
# 37         Colombia     257101    8777     131161   117163      16306
# 61           France     220352   30212      81212   108928       2551
# 65          Germany     207112    9125     190314     7673        445
# 79            India    1480073   33408     951166   495499      44457
# 80        Indonesia     100303    4838      58173    37292       1525
# 81             Iran     293606   15912     255144    22550       2434
# 82             Iraq     112585    4458      77144    30983       2553
# ...

# %%
data2.shape
# Out:
# (24, 15)

# %% [markdown]
# # 3) In which region, maximum number of Confirmed cases were recorded?

# %%
data2 = pd.read_csv("/Users/archanaqueen/Desktop/i18n/Python Projects/Covid-19 dataset/country_wise_latest.csv")

# %%
data2
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2.groupby("WHO Region")["Confirmed"].sum().sort_values(ascending = False)
# Out:
# WHO Region
# Americas                 8839286
# Europe                   3299523
# South-East Asia          1835297
# Eastern Mediterranean    1490744
# Africa                    723207
# Western Pacific           292428
# Name: Confirmed, dtype: int64

# %%
# Hence Americas are having the maximum number of confirmed cases

# %% [markdown]
# # 4) In which Region, minimum number of Deaths cases were recorded?

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2.groupby("WHO Region")["Deaths"].sum().sort_values(ascending = True)
# Out:
# WHO Region
# Western Pacific            8249
# Africa                    12223
# Eastern Mediterranean     38339
# South-East Asia           41349
# Europe                   211144
# Americas                 342732
# Name: Deaths, dtype: int64

# %%
# Hence, here minimum number of deaths recorded in Western Pacific Region

# %% [markdown]
# # 5) How many Confirmed, Deaths & Recovered cases were reported from Americas

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2["WHO Region"]
# Out:
# 0      Eastern Mediterranean
# 1                     Europe
# 2                     Africa
# 3                     Europe
# 4                     Africa
#                ...
# 182    Eastern Mediterranean
# 183                   Africa
# 184    Eastern Mediterranean
# 185                   Africa
# 186                   Africa
# Name: WHO Region, Length: 187, dtype: object

# %%
data2["WHO Region"].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
data2["WHO Region"] == "Americas"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: WHO Region, Length: 187, dtype: bool

# %%
data2[data2["WHO Region"] == "Americas"]
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered   Active  \
# 5                 Antigua and Barbuda         86       3         65       18
# 6                           Argentina     167416    3059      72575    91782
# 11                            Bahamas        382      11         91      280
# 14                           Barbados        110       7         94        9
# 17                             Belize         48       2         26       20
# 20                            Bolivia      71181    2647      21478    47056
# 23                             Brazil    2442375   87618    1846641   508116
# 32                             Canada     116458    8944          0   107514
# 35                              Chile     347923    9187     319954    18782
# 37                           Colombia     257101    8777     131161   117163
# 41                         Costa Rica      15841     115       3824    11902
# ...

# %%
data2[["Deaths","Confirmed","Recovered"]].sum()
# Out:
# Deaths         654036
# Confirmed    16480485
# Recovered     9468087
# dtype: int64

# %% [markdown]
# # 6) Sort the entire data with respect to No.of confirmed cases in ascending order

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2.sort_values(by="Confirmed",ascending=True).head(20)
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 183                    Western Sahara         10       1          8       1
# 75                           Holy See         12       0         12       0
# 68                          Greenland         14       0         13       1
# 140             Saint Kitts and Nevis         17       0         15       2
# 49                           Dominica         18       0         18       0
# 94                               Laos         20       0         19       1
# 69                            Grenada         23       0         23       0
# 168                       Timor-Leste         24       0          0      24
# 141                       Saint Lucia         24       0         22       2
# 59                               Fiji         27       0         18       9
# 17                             Belize         48       2         26      20
# ...

# %% [markdown]
# # 7) Sort the entire data with respect to No.of Recovered cases in descending order

# %%
data2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data2.sort_values(by="Confirmed",ascending=False).head(20)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 79            India    1480073   33408     951166   495499      44457
# 138          Russia     816680   13334     602249   201097       5607
# 154    South Africa     452529    7067     274925   170537       7096
# 111          Mexico     395489   44022     303810    47657       4973
# 132            Peru     389717   18418     272547    98752      13756
# 35            Chile     347923    9187     319954    18782       2133
# 177  United Kingdom     301708   45844       1437   254427        688
# 81             Iran     293606   15912     255144    22550       2434
# 128        Pakistan     274289    5842     241026    27421       1176
# 157           Spain     272421   28432     150376    93613          0
# ...
