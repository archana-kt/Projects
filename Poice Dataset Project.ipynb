# %% [markdown]
# # Python Project

# %% [markdown]
# # Police Dataset

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/archanaqueen/Desktop/i18n/Python Projects/Police Dataset/shootings_wash_post.csv")

# %%
data
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5547  6048               TK TK  2020-08-15              shot         knife
# 5548  6042        Thomas Moles  2020-08-16              shot  undetermined
# 5549  6043  Jose Manuel Castro  2020-08-16              shot         knife
# 5550  6044     Jeffrey Hubbard  2020-08-16              shot           gun
# 5551  6045               TK TK  2020-08-16              shot           gun
#
# ...

# %%
data.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
data.shape
# Out:
# (5552, 14)

# %%
data.dtypes
# Out:
# id                           int64
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5552 entries, 0 to 5551
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       5552 non-null   int64
#  1   name                     5552 non-null   object
#  2   date                     5552 non-null   object
#  3   manner_of_death          5552 non-null   object
#  4   armed                    5339 non-null   object
#  5   age                      5307 non-null   float64
#  6   gender                   5551 non-null   object
#  7   race                     4966 non-null   object
#  8   city                     5552 non-null   object
#  9   state                    5552 non-null   object
#  10  signs_of_mental_illness  5552 non-null   bool
#  11  threat_level             5552 non-null   object
#  12  flee                     5290 non-null   object
#  13  body_camera              5552 non-null   bool
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # 1) Remove the null values columns

# %%
data.isnull()
# Out:
#          id   name   date  manner_of_death  armed    age  gender   race  \
# 0     False  False  False            False  False  False   False  False
# 1     False  False  False            False  False  False   False  False
# 2     False  False  False            False  False  False   False  False
# 3     False  False  False            False  False  False   False  False
# 4     False  False  False            False  False  False   False  False
# ...     ...    ...    ...              ...    ...    ...     ...    ...
# 5547  False  False  False            False  False   True   False   True
# 5548  False  False  False            False  False  False   False  False
# 5549  False  False  False            False  False  False   False  False
# 5550  False  False  False            False  False  False   False  False
# 5551  False  False  False            False  False  False   False   True
#
#        city  state  signs_of_mental_illness  threat_level   flee  body_camera
# ...

# %%
data.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                      213
# age                        245
# gender                       1
# race                       586
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       262
# body_camera                  0
# dtype: int64

# %%
data['age']
# Out:
# 0       53.0
# 1       47.0
# 2       23.0
# 3       32.0
# 4       39.0
#         ...
# 5547     NaN
# 5548    35.0
# 5549    27.0
# 5550    67.0
# 5551    30.0
# Name: age, Length: 5552, dtype: float64

# %%
data.drop(columns = 'age', inplace = True)

# %%
data.head()
# Out:
#    id                name        date   manner_of_death       armed gender  \
# 0   3          Tim Elliot  2015-01-02              shot         gun      M
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun      M
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed      M
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon      M
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0    A        Shelton    WA                     True       attack
# 1    W          Aloha    OR                    False       attack
# 2    H        Wichita    KS                    False        other
# 3    W  San Francisco    CA                     True       attack
# 4    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# ...

# %%
data.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                      213
# gender                       1
# race                       586
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       262
# body_camera                  0
# dtype: int64

# %% [markdown]
# # Filtering

# %% [markdown]
# # 2) For shot and Tasered, were attack or other shot and Tasered more often?

# %%
data.head()
# Out:
#    id                name        date   manner_of_death       armed gender  \
# 0   3          Tim Elliot  2015-01-02              shot         gun      M
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun      M
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed      M
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon      M
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0    A        Shelton    WA                     True       attack
# 1    W          Aloha    OR                    False       attack
# 2    H        Wichita    KS                    False        other
# 3    W  San Francisco    CA                     True       attack
# 4    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# ...

# %%
data['threat_level'].unique()
# Out:
# array(['attack', 'other', 'undetermined'], dtype=object)

# %%
data["manner_of_death"] == "shot"
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 5547     True
# 5548     True
# 5549     True
# 5550     True
# 5551     True
# Name: manner_of_death, Length: 5552, dtype: bool

# %%
data[data["manner_of_death"] == "shot and Tasered"]
# Out:
#         id                name        date   manner_of_death    armed gender  \
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered  unarmed      M
# 10      19      Patrick Wetter  2015-01-06  shot and Tasered    knife      M
# 23      45   Salvador Figueroa  2015-01-11  shot and Tasered      gun      M
# 38      68       Zaki Shinwary  2015-01-16  shot and Tasered    knife      M
# 43      83       Carter Castle  2015-01-18  shot and Tasered      gun      M
# ...    ...                 ...         ...               ...      ...    ...
# 5424  5939      Brandeis Codde  2020-06-21  shot and Tasered    knife      M
# 5446  5951     Aloysius Keaton  2020-06-27  shot and Tasered    knife      M
# 5456  5959        Kevan Ruffin  2020-07-02  shot and Tasered    knife      M
# 5510  6029      Darrien Walker  2020-07-30  shot and Tasered    sword      M
# 5515  6018   Adrean Stephenson  2020-08-02  shot and Tasered    knife      F
#
# ...

# %%
data["manner_of_death"].value_counts()
# Out:
# shot                5275
# shot and Tasered     277
# Name: manner_of_death, dtype: int64

# %%
data[(data["threat_level"] == "attack") | (data["threat_level"] == "other")]
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5547  6048               TK TK  2020-08-15              shot         knife
# 5548  6042        Thomas Moles  2020-08-16              shot  undetermined
# 5549  6043  Jose Manuel Castro  2020-08-16              shot         knife
# 5550  6044     Jeffrey Hubbard  2020-08-16              shot           gun
# 5551  6045               TK TK  2020-08-16              shot           gun
#
# ...

# %%
data[(data["manner_of_death"] == "shot and Tasered") & (data["threat_level"] == "attack") | (data["threat_level"] == "other")]
# Out:
#         id                            name        date   manner_of_death  \
# 2        5              John Paul Quintero  2015-01-03  shot and Tasered
# 8       16                   Autumn Steele  2015-01-06              shot
# 10      19                  Patrick Wetter  2015-01-06  shot and Tasered
# 12      22  Hashim Hanif Ibn Abdul-Rasheed  2015-01-07              shot
# 23      45               Salvador Figueroa  2015-01-11  shot and Tasered
# ...    ...                             ...         ...               ...
# 5545  6046                 Anthony McClain  2020-08-15              shot
# 5548  6042                    Thomas Moles  2020-08-16              shot
# 5549  6043              Jose Manuel Castro  2020-08-16              shot
# 5550  6044                 Jeffrey Hubbard  2020-08-16              shot
# 5551  6045                           TK TK  2020-08-16              shot
#
#              armed gender race             city state  \
# ...

# %% [markdown]
# # Groupby

# %% [markdown]
# # 3) Does gender affect who gets signs_of_mental_illness?

# %%
data.head()
# Out:
#    id                name        date   manner_of_death       armed gender  \
# 0   3          Tim Elliot  2015-01-02              shot         gun      M
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun      M
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed      M
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon      M
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0    A        Shelton    WA                     True       attack
# 1    W          Aloha    OR                    False       attack
# 2    H        Wichita    KS                    False        other
# 3    W  San Francisco    CA                     True       attack
# 4    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# ...

# %%
data["gender"].value_counts()
# Out:
# M    5305
# F     246
# Name: gender, dtype: int64

# %%
data.groupby("gender").signs_of_mental_illness.sum()
# Out:
# gender
# F      76
# M    1167
# Name: signs_of_mental_illness, dtype: int64

# %%
data.signs_of_mental_illness.value_counts()
# Out:
# False    4308
# True     1244
# Name: signs_of_mental_illness, dtype: int64

# %%
# Based on this, 1244 times affected on 26-Female and 1167-Male

# %% [markdown]
# # Mapping & data-type casting

# %%
data.head()
# Out:
#    id                name        date   manner_of_death       armed gender  \
# 0   3          Tim Elliot  2015-01-02              shot         gun      M
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun      M
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed      M
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon      M
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun      M
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0    A        Shelton    WA                     True       attack
# 1    W          Aloha    OR                    False       attack
# 2    H        Wichita    KS                    False        other
# 3    W  San Francisco    CA                     True       attack
# 4    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# ...

# %% [markdown]
# # Groupby,Describe

# %% [markdown]
# # 5) Compare the manner_of_death distributions for each threat_level

# %%
data.groupby("threat_level").manner_of_death.describe()
# Out:
#              count unique   top  freq
# threat_level
# attack        3591      2  shot  3451
# other         1714      2  shot  1584
# undetermined   247      2  shot   240
